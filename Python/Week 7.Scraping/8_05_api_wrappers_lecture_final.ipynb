# %%
# import necessary spotipy tools
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import getpass

# %%
client_id = str(getpass.getpass('client_id?'))
client_secret = str(getpass.getpass('client_secret?'))
# Out:
# client_id?········
# client_secret?········

# %%
# connect to the API
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="c775f2fba4064b8d89a723f0eb3c4015",
                                                          client_secret="0a1f7dca5ce74bed98f584a787308024"))

# %%
results = sp.search(q="Lady Gaga", limit=50)

# %% [markdown]
# # Activity 1
# In order to use the `Spotify` API (`SpotiPy`), create an account in `Spotify` and follow [these](https://developer.spotify.com/documentation/general/guides/app-settings/) steps. Once you have done it, work on the following instructions:
#
# - Create a list with your favourite (5 - 20?) artists, like `artists = ['Tycho', 'Who made who', ... ]`.
# - Loop over your artists, querying them using the Spotipy API (`sp.search( ... )` ) like we did in lecture and store their search results in an equally long list `my_20_artists`  (list comprehension? 🙂)
# - Generalize it! In a similar way now, create a function that takes a list of artist names and return their 50 first appearances as a dictionary.
#
# ```python
# {'tycho': [ search results ],
#  'who made who' : [ search results ],
#
#  ....
# }
# ```

# %%
artists = ['Marc Rebillet',
           'Modeselektor',
           'Who Made Who',
           'Hildegard von Blingin']

# %%
# phine with append
my_20_artists = []
for artist in artists:
    my_20_artists.append(sp.search(q={artist}, limit=50)) 

# marian list comprehension
my_20_artists = [sp.search(q=artist, limit=50) for artist in artists]

# %%
my_20_artists
# Out:
# [{'tracks': {'href': 'https://api.spotify.com/v1/search?query=Marc+Rebillet&type=track&offset=0&limit=50',
#    'items': [{'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72udTJKu1pGovvS9aCYGMI'},
#         'href': 'https://api.spotify.com/v1/artists/72udTJKu1pGovvS9aCYGMI',
#         'id': '72udTJKu1pGovvS9aCYGMI',
#         'name': 'Marc Rebillet',
#         'type': 'artist',
#         'uri': 'spotify:artist:72udTJKu1pGovvS9aCYGMI'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
# ...

# %% [markdown]
# ### second part of the activity

# %%
artists = ['Marc Rebillet',
           'Modeselektor',
           'Who Made Who',
           'Hildegard von Blingin']

def artist_to_dict(artists):
    return {artist:sp.search(q=artist, limit=50) for artist in artists}

len(artist_to_dict(artists))
# Out:
# 4

# %%
# dictionary comprehension
{str(key):key**2 for key in range(10)}#

# same thing with a for loop
dct = {}
for key in range(10):
    dct[str(key)] = key**2

dct
# Out:
# {'0': 0,
#  '1': 1,
#  '2': 4,
#  '3': 9,
#  '4': 16,
#  '5': 25,
#  '6': 36,
#  '7': 49,
#  '8': 64,
#  '9': 81}

# %% [markdown]
# # Let's explore items

# %%
results = sp.search(q="Lady Gaga", limit=50)

# %%
type(results)

# %%
results.keys()

# %%
results

# %%
results.keys()

# %%
results['tracks']

# %%
results['tracks'].keys()

# %%
results['tracks']['href']

# %%
results['tracks']['items']

# %%
results['tracks']['limit']

# %%
results['tracks']['next']

# %%
results['tracks']['offset']

# %%
results['tracks']['previous']

# %%
results['tracks']['total']

# %%
len(results['tracks']['items'])

# %%
# for first song:
results['tracks']['items'][0].keys()

# %%
# checking the content of the first song (index 0), album!
results["tracks"]["items"][0]["album"] # we have more info about the album

# %%
results["tracks"]["items"][0]["album"].keys() # Will check artists, id, name, release date, total tracks

# %%
results["tracks"]["items"][0]["album"]["artists"] # List with artists and information

# %%
results["tracks"]["items"][0]["album"]["id"] # Album ID

# %%
results["tracks"]["items"][0]["album"]["name"] # Album name (if its a single u'll get the name of the song)

# %%
results["tracks"]["items"][0]["album"]["release_date"] #date in YYYY-MM-DD format

# %%
results["tracks"]["items"][0]["album"]["total_tracks"] #songs in the album

# %%
# More info of the first song

# %%
results["tracks"]["items"][0]["artists"] # Track artists

# %%
results["tracks"]["items"][0]["id"] # Track ID

# %%
results["tracks"]["items"][0]["name"] # Track name

# %%
results["tracks"]["items"][0]["popularity"] # Popularity index

# %%
results["tracks"]["items"][0]["uri"] # Basically ID

# %% [markdown]
# # Activity 2

# %%
my_track =

# %%
my_track['artists']

# %% [markdown]
# ### Activity 2 solution

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

def get_artists_ids_from_track(track):
    return [artist["id"] for artist in track["artists"]]

# %%
get_artists_ids_from_track(results["tracks"]["items"][0])

# %% [markdown]
# # Playlists!

# %% [markdown]
# **Categories** -> get all the **playlists** (IDs) in that category -> get all the **songs** (IDs) from all playlists (together with their audio feature) -> get all the audio features with these IDs

# %% [markdown]
# Playlist link:
# https://open.spotify.com/playlist/75GeX247deNdTX7zdyZDnU?si=29f55c0ba7d84da0
#
# From that this is the ID: **75GeX247deNdTX7zdyZDnU**

# %%
playlist = sp.user_playlist_tracks("patrickimoh", "75GeX247deNdTX7zdyZDnU")

# %%
len(playlist['items'])

# %% [markdown]
# Overall goal of this part of gnod is **a dataframe** like this
#
# artist | title | id | accousticness | dancability | ... | ...
# --- | --- | --- | --- | --- | --- | ---
#  |  |  |  |  |  |

# %% [markdown]
# **Target: Get all the ID's for all the songs in that playlist!**

# %%
# let's get the ID for only one song first!
playlist['items'][0]['track']['id']

# here i make it work for the whole playlist
for item in playlist['items']:
    print(item['track']['id'])

nigeriantop100 = []
for item in playlist['items']:
    nigeriantop100.append(item['track']['id'])

# %%
nigeriantop100

# %%
# these are the audio features for all songs in the playlist
sp.audio_features(tracks=nigeriantop100)

# %%
audio_features_nigeria = pd.DataFrame(sp.audio_features(tracks=nigeriantop100))

# %%
audio_features_nigeria.head()

# %%
ls

# %%
from IPython.display import display, Image
display(Image(filename='gnod_1st_prototype.jpg'))

# %%
from IPython.display import display, Image
display(Image(filename='gnod_2nd_prototype.jpg'))

# %% [markdown]
# ### How to get the spotify categories

# %%
sp.categories(limit=50)

# %%
# get all the id's for all the categories
[item['id'] for item in sp.categories(limit=50)['categories']['items']]

# %% [markdown]
# oh noooo! categories seem to be different everytime we query the API

# %%
lst1 = [item['id'] for item in sp.categories(limit=50)['categories']['items']]

# %%
lst2 = [item['id'] for item in sp.categories(limit=50)['categories']['items']]

# %%
set(lst1) == set(lst2)
