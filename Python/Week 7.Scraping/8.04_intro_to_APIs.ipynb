# %%
ls
# Out:
#  8.04_intro_to_APIs.ipynb                           gnod_cluster_algorithm.jpg
# "8.04_intro _to_API's_lecture_part_3-Copy1.ipynb"   gnod_clustering.jpg
# "8.04_intro _to_API's_lecture_part_3.ipynb"         img_htmltree.gif
#  8.04_intro_to_APIs.pptx                            ipynb/
#  car.jpg                                            lesson.md
#  gnod_1st_iteration.jpg                             phone.jpg
#  gnod_1st_prototype.jpg                             restaurant.jpg
#  gnod_2nd_iteration.jpg                             what-is-api.jpg
#  gnod_2nd_prototype.jpg

# %% [markdown]
# # 8.04 - Intro to API's

# %%
from IPython.display import display, Image
display(Image(filename='gnod_1st_iteration.jpg'))

# %%
display(Image(filename='gnod_2nd_iteration.jpg'))

# %%
a = "hello world"

# %%
len(a)
# Out:
# 11

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
a
# Out:
# 'hello world'

# %%
a + "dsafd"
# Out:
# 'hello worlddsafd'

# %%
a.__add__("dsafd")
# Out:
# 'hello worlddsafd'

# %%
display(Image(filename='restaurant.jpg'))

# %% [markdown]
# # REST APIs

# %% [markdown]
# ### REST APIs
#
# * (**RE**presentational **S**tate **T**ransfer)
# * Most popular way (paradigm) in which web services are structured nowaday
# * And so are REST APIs.
# * REST defines 6 architectural constraints#
# * Those make any web service a RESTful API.
# * You can find them [here](https://www.geeksforgeeks.org/rest-api-architectural-constraints/#:~:text=The%20only%20optional%20constraint%20of,API%20and%20Non-REST%20API.&text=For%20example%3A%20API%2Fusers.). (These concepts can be explained to more advanced classes, added as **optional** content)
#
# * REST aims for a unified standard of interfaces
# * This is important because it generalizes the use of **HTTP** (hypertext transfer protocol). how clients and servers make **requests** among each other.
# * It is the tool we will be using when interacting with an API.
# * Like a python object, HTTP has different methods, including the most important ones **GET** and **POST**. We will take a look at it in the next lesson.

# %%
# Import requests library
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA =  requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# * `200`: Everything went ok
# * `301`: The server is redirecting you to a different endpoint
# * `400`: The server thinks you mad a bad request. You're not sending the right data for a request
# * `401`: You're not properly authenticated
# * `403`: Resource you're trying to access is forbidden
# * `404`: Resource does not exist
# * `503`: The server can't handle the request

# %% [markdown]
# # Use the skyscanner API from rapidapi

# %% [markdown]
# [link](https://rapidapi.com/skyscanner/api/skyscanner-flight-search) to the API

# %%
import getpass
# your rapid-api key here
api_key = getpass.getpass()

# %%
import requests

# send a GET request for locations 
url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/autosuggest/v1.0/UK/GBP/en-GB/"

querystring = {"query":"Stockholm"}

headers = {
    'x-rapidapi-key': "",
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#   "Places" : [ {
#     "PlaceId" : "STOC-sky",
#     "PlaceName" : "Stockholm",
#     "CountryId" : "SE-sky",
#     "RegionId" : "",
#     "CityId" : "STOC-sky",
#     "CountryName" : "Sweden"
#   }, {
#     "PlaceId" : "ARN-sky",
#     "PlaceName" : "Stockholm Arlanda",
#     "CountryId" : "SE-sky",
#     "RegionId" : "",
#     "CityId" : "STOC-sky",
#     "CountryName" : "Sweden"
#   }, {
#     "PlaceId" : "NYO-sky",
#     "PlaceName" : "Stockholm Skavsta",
#     "CountryId" : "SE-sky",
#     "RegionId" : "",
#     "CityId" : "STOC-sky",
#     "CountryName" : "Sweden"
#   }, {
#     "PlaceId" : "BMA-sky",
#     "PlaceName" : "Stockholm Bromma",
#     "CountryId" : "SE-sky",
#     "RegionId" : "",
#     "CityId" : "STOC-sky",
#     "CountryName" : "Sweden"
#   }, {
#     "PlaceId" : "VST-sky",
#     "PlaceName" : "Stockholm Vasteras",
#     "CountryId" : "SE-sky",
#     "RegionId" : "",
#     "CityId" : "STOC-sky",
#     "CountryName" : "Sweden"
#   } ]
# }

# %%
# send a GET request for location "Tokyo"
url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/autosuggest/v1.0/UK/GBP/en-GB/"

params = {"query":"Tokyo"}

headers = {'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
        'x-rapidapi-key': str(api_key)}

response = requests.get(url, headers = headers, params = params)
response.json()
# Out:
# {'Places': [{'PlaceId': 'TYOA-sky',
#    'PlaceName': 'Tokyo',
#    'CountryId': 'JP-sky',
#    'RegionId': '',
#    'CityId': 'TYOA-sky',
#    'CountryName': 'Japan'},
#   {'PlaceId': 'NRT-sky',
#    'PlaceName': 'Tokyo Narita',
#    'CountryId': 'JP-sky',
#    'RegionId': '',
#    'CityId': 'TYOA-sky',
#    'CountryName': 'Japan'},
#   {'PlaceId': 'HND-sky',
#    'PlaceName': 'Tokyo Haneda',
#    'CountryId': 'JP-sky',
#    'RegionId': '',
#    'CityId': 'TYOA-sky',
#    'CountryName': 'Japan'},
#   {'PlaceId': 'TJH-sky',
#    'PlaceName': 'Toyooka',
#    'CountryId': 'JP-sky',
#    'RegionId': '',
#    'CityId': 'JTJH-sky',
#    'CountryName': 'Japan'},
#   {'PlaceId': 'OOK-sky',
#    'PlaceName': 'Toksook Bay',
#    'CountryId': 'US-sky',
#    'RegionId': 'AK',
#    'CityId': 'OOKA-sky',
#    'CountryName': 'United States'},
#   {'PlaceId': 'TKZ-sky',
#    'PlaceName': 'Tokoroa',
#    'CountryId': 'NZ-sky',
#    'RegionId': '',
#    'CityId': 'TKZN-sky',
#    'CountryName': 'New Zealand'}]}

# %%
# send a request for flight quotes from San Francisco to New York

url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsequotes/v1.0/US/USD/en-US/SFO-sky/NYCA-sky/anytime"

params = {"inboundpartialdate":"2021-12-12"}

headers = {
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
    'x-rapidapi-key': str(api_key)}

response = requests.get(url, headers=headers, params=params)

response.json()
# Out:
# {'Quotes': [{'QuoteId': 1,
#    'MinPrice': 96,
#    'Direct': False,
#    'OutboundLeg': {'CarrierIds': [1065],
#     'OriginId': 81727,
#     'DestinationId': 65633,
#     'DepartureDate': '2021-05-18T00:00:00'},
#    'QuoteDateTime': '2021-05-01T08:59:00'},
#   {'QuoteId': 2,
#    'MinPrice': 118,
#    'Direct': True,
#    'OutboundLeg': {'CarrierIds': [851],
#     'OriginId': 81727,
#     'DestinationId': 60987,
#     'DepartureDate': '2021-10-19T00:00:00'},
#    'QuoteDateTime': '2021-04-30T14:56:00'},
#   {'QuoteId': 3,
#    'MinPrice': 118,
#    'Direct': True,
#    'OutboundLeg': {'CarrierIds': [851],
#     'OriginId': 81727,
#     'DestinationId': 60987,
#     'DepartureDate': '2021-12-03T00:00:00'},
#    'QuoteDateTime': '2021-05-04T11:48:00'},
#   {'QuoteId': 4,
#    'MinPrice': 119,
#    'Direct': True,
#    'OutboundLeg': {'CarrierIds': [851],
#     'OriginId': 81727,
#     'DestinationId': 60987,
#     'DepartureDate': '2021-11-01T00:00:00'},
#    'QuoteDateTime': '2021-05-03T07:12:00'},
#   {'QuoteId': 5,
#    'MinPrice': 119,
#    'Direct': True,
#    'OutboundLeg': {'CarrierIds': [851],
#     'OriginId': 81727,
#     'DestinationId': 60987,
#     'DepartureDate': '2022-01-19T00:00:00'},
#    'QuoteDateTime': '2021-05-03T12:41:00'},
#   {'QuoteId': 6,
#    'MinPrice': 123,
#    'Direct': True,
#    'OutboundLeg': {'CarrierIds': [851],
#     'OriginId': 81727,
#     'DestinationId': 60987,
#     'DepartureDate': '2021-09-30T00:00:00'},
#    'QuoteDateTime': '2021-05-02T01:25:00'},
#   {'QuoteId': 7,
#    'MinPrice': 124,
#    'Direct': False,
#    'OutboundLeg': {'CarrierIds': [851],
#     'OriginId': 81727,
#     'DestinationId': 65633,
#     'DepartureDate': '2021-07-07T00:00:00'},
#    'QuoteDateTime': '2021-05-04T03:21:00'},
#   {'QuoteId': 8,
#    'MinPrice': 124,
#    'Direct': False,
#    'OutboundLeg': {'CarrierIds': [851],
#     'OriginId': 81727,
#     'DestinationId': 65633,
#     'DepartureDate': '2021-08-31T00:00:00'},
#    'QuoteDateTime': '2021-05-03T19:27:00'},
#   {'QuoteId': 9,
#    'MinPrice': 125,
#    'Direct': False,
#    'OutboundLeg': {'CarrierIds': [851],
#     'OriginId': 81727,
#     'DestinationId': 65633,
#     'DepartureDate': '2021-10-30T00:00:00'},
#    'QuoteDateTime': '2021-05-01T14:57:00'},
#   {'QuoteId': 10,
#    'MinPrice': 125,
#    'Direct': False,
#    'OutboundLeg': {'CarrierIds': [851],
#     'OriginId': 81727,
#     'DestinationId': 65633,
#     'DepartureDate': '2021-09-22T00:00:00'},
#    'QuoteDateTime': '2021-05-03T13:40:00'},
#   {'QuoteId': 11,
#    'MinPrice': 125,
#    'Direct': True,
#    'OutboundLeg': {'CarrierIds': [1793],
#     'OriginId': 81727,
#     'DestinationId': 60987,
#     'DepartureDate': '2021-08-10T00:00:00'},
#    'QuoteDateTime': '2021-05-02T15:13:00'},
#   {'QuoteId': 12,
#    'MinPrice': 125,
#    'Direct': True,
#    'OutboundLeg': {'CarrierIds': [870],
#     'OriginId': 81727,
#     'DestinationId': 60987,
#     'DepartureDate': '2021-07-27T00:00:00'},
#    'QuoteDateTime': '2021-04-30T14:03:00'},
#   {'QuoteId': 13,
#    'MinPrice': 126,
#    'Direct': True,
#    'OutboundLeg': {'CarrierIds': [870],
#     'OriginId': 81727,
#     'DestinationId': 50290,
#     'DepartureDate': '2021-06-10T00:00:00'},
#    'QuoteDateTime': '2021-05-03T18:06:00'},
#   {'QuoteId': 14,
#    'MinPrice': 126,
#    'Direct': True,
#    'OutboundLeg': {'CarrierIds': [1793],
#     'OriginId': 81727,
#     'DestinationId': 60987,
#     'DepartureDate': '2022-02-19T00:00:00'},
#    'QuoteDateTime': '2021-05-01T16:00:00'},
#   {'QuoteId': 15,
#    'MinPrice': 130,
#    'Direct': True,
#    'OutboundLeg': {'CarrierIds': [870],
#     'OriginId': 81727,
#     'DestinationId': 50290,
#     'DepartureDate': '2021-05-17T00:00:00'},
#    'QuoteDateTime': '2021-05-04T04:02:00'},
#   {'QuoteId': 16,
#    'MinPrice': 131,
#    'Direct': True,
#    'OutboundLeg': {'CarrierIds': [851],
#     'OriginId': 81727,
#     'DestinationId': 60987,
#     'DepartureDate': '2022-03-21T00:00:00'},
#    'QuoteDateTime': '2021-05-03T13:32:00'},
#   {'QuoteId': 17,
#    'MinPrice': 135,
#    'Direct': False,
#    'OutboundLeg': {'CarrierIds': [1793],
#     'OriginId': 81727,
#     'DestinationId': 60987,
#     'DepartureDate': '2021-11-25T00:00:00'},
#    'QuoteDateTime': '2021-04-30T16:19:00'},
#   {'QuoteId': 18,
#    'MinPrice': 145,
#    'Direct': False,
#    'OutboundLeg': {'CarrierIds': [1065],
#     'OriginId': 81727,
#     'DestinationId': 50290,
#     'DepartureDate': '2021-06-23T00:00:00'},
#    'QuoteDateTime': '2021-05-03T20:23:00'},
#   {'QuoteId': 19,
#    'MinPrice': 179,
#    'Direct': True,
#    'OutboundLeg': {'CarrierIds': [1793],
#     'OriginId': 81727,
#     'DestinationId': 50290,
#     'DepartureDate': '2022-04-01T00:00:00'},
#    'QuoteDateTime': '2021-05-03T23:54:00'},
#   {'QuoteId': 20,
#    'MinPrice': 268,
#    'Direct': False,
#    'OutboundLeg': {'CarrierIds': [851],
#     'OriginId': 81727,
#     'DestinationId': 60987,
#     'DepartureDate': '2022-03-25T00:00:00'},
#    'QuoteDateTime': '2021-05-03T14:29:00'}],
#  'Carriers': [{'CarrierId': 1065, 'Name': 'Frontier Airlines'},
#   {'CarrierId': 851, 'Name': 'Alaska Airlines'},
#   {'CarrierId': 1793, 'Name': 'United'},
#   {'CarrierId': 870, 'Name': 'jetBlue'}],
#  'Places': [{'Name': 'New York Newark',
#    'Type': 'Station',
#    'PlaceId': 50290,
#    'IataCode': 'EWR',
#    'SkyscannerCode': 'EWR',
#    'CityName': 'New York',
#    'CityId': 'NYCA',
#    'CountryName': 'United States'},
#   {'Name': 'New York John F. Kennedy',
#    'Type': 'Station',
#    'PlaceId': 60987,
#    'IataCode': 'JFK',
#    'SkyscannerCode': 'JFK',
#    'CityName': 'New York',
#    'CityId': 'NYCA',
#    'CountryName': 'United States'},
#   {'Name': 'New York LaGuardia',
#    'Type': 'Station',
#    'PlaceId': 65633,
#    'IataCode': 'LGA',
#    'SkyscannerCode': 'LGA',
#    'CityName': 'New York',
#    'CityId': 'NYCA',
#    'CountryName': 'United States'},
#   {'Name': 'San Francisco International',
#    'Type': 'Station',
#    'PlaceId': 81727,
#    'IataCode': 'SFO',
#    'SkyscannerCode': 'SFO',
#    'CityName': 'San Francisco',
#    'CityId': 'SFOA',
#    'CountryName': 'United States'}],
#  'Currencies': [{'Code': 'USD',
#    'Symbol': '$',
#    'ThousandsSeparator': ',',
#    'DecimalSeparator': '.',
#    'SymbolOnLeft': True,
#    'SpaceBetweenAmountAndSymbol': False,
#    'RoundingCoefficient': 0,
#    'DecimalDigits': 2}]}

# %%
# Import libraries
import pandas as pd
import json

# Normalize the response
pd.json_normalize(response.json())
# Out:
#                                               Quotes  \
# 0  [{'QuoteId': 1, 'MinPrice': 96, 'Direct': Fals...
#
#                                             Carriers  \
# 0  [{'CarrierId': 1065, 'Name': 'Frontier Airline...
#
#                                               Places  \
# 0  [{'Name': 'New York Newark', 'Type': 'Station'...
#
#                                           Currencies
# 0  [{'Code': 'USD', 'Symbol': '$', 'ThousandsSepa...

# %%
quotes = pd.DataFrame(pd.json_normalize(response.json())['Quotes'][0])
carriers = pd.DataFrame(pd.json_normalize(response.json())['Carriers'][0])
places = pd.DataFrame(pd.json_normalize(response.json())['Places'][0])
currencies = pd.DataFrame(pd.json_normalize(response.json())['Currencies'][0])

# %%
quotes.head()
# Out:
#    QuoteId  MinPrice  Direct  \
# 0        1        96   False
# 1        2       118    True
# 2        3       118    True
# 3        4       119    True
# 4        5       119    True
#
#                                          OutboundLeg        QuoteDateTime
# 0  {'CarrierIds': [1065], 'OriginId': 81727, 'Des...  2021-05-01T08:59:00
# 1  {'CarrierIds': [851], 'OriginId': 81727, 'Dest...  2021-04-30T14:56:00
# 2  {'CarrierIds': [851], 'OriginId': 81727, 'Dest...  2021-05-04T11:48:00
# 3  {'CarrierIds': [851], 'OriginId': 81727, 'Dest...  2021-05-03T07:12:00
# 4  {'CarrierIds': [851], 'OriginId': 81727, 'Dest...  2021-05-03T12:41:00

# %%
carriers.head()
# Out:
#    CarrierId               Name
# 0       1065  Frontier Airlines
# 1        851    Alaska Airlines
# 2       1793             United
# 3        870            jetBlue

# %%
places.head()
# Out:
#                           Name     Type  PlaceId IataCode SkyscannerCode  \
# 0              New York Newark  Station    50290      EWR            EWR
# 1     New York John F. Kennedy  Station    60987      JFK            JFK
# 2           New York LaGuardia  Station    65633      LGA            LGA
# 3  San Francisco International  Station    81727      SFO            SFO
#
#         CityName CityId    CountryName
# 0       New York   NYCA  United States
# 1       New York   NYCA  United States
# 2       New York   NYCA  United States
# 3  San Francisco   SFOA  United States

# %%
currencies
# Out:
#   Code Symbol ThousandsSeparator DecimalSeparator  SymbolOnLeft  \
# 0  USD      $                  ,                .          True
#
#    SpaceBetweenAmountAndSymbol  RoundingCoefficient  DecimalDigits
# 0                        False                    0              2

# %% [markdown]
# Looks like a relational database packed into this JSON with a primary / foreign key structure!
