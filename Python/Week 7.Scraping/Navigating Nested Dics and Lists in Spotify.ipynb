# %%
#Client ID: c775f2fba4064b8d89a723f0eb3c4015
#Client Secret: 0a1f7dca5ce74bed98f584a787308024
importr

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import getpass

# %%
client_id = str(getpass.getpass('client_id?'))
client_secret = str(getpass.getpass('client_secret?'))
# Out:
# client_id?········
# client_secret?········

# %%
#connecct to api
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="c775f2fba4064b8d89a723f0eb3c4015",
                                                          client_secret="0a1f7dca5ce74bed98f584a787308024"))

# %% [markdown]
# #### In general you can get a lot of functions from the existing spotify libraries.

# %%
#this generates a list of all the items in spotify (up to 50) you get when you search for lady gaga on the home page. 
results = sp.search(q="Lady Gaga", limit=50)

# %%
#what is this value?
type(results)
# Out:
# dict

# %%
#Its a big print out. how can we navigate it. Let's have a look at what the keys are: 
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
#Ah great. So lets look up what values sits under 'tracks'
results['tracks']
# Out:
# {'href': 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50',
#  'items': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
# ...

# %%
# humm. that's still 
# a lot of text I dont need. How can I drill down further?
# - ltst see if there are any more keys nested in tracks
results['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
#ah nice. Now I can reference them too. 
results['tracks']['items']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
# ...

# %%
#damn. Still a big mess. lets see if there are more keys
results['tracks']['items'].keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-11c7d2613187> in <module>
#       1 #damn. Still a big mess. lets see if there are more keys
# ----> 2 results['tracks']['items'].keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
# nope. Doesnt work. why?
type(results['tracks']['items'])
# Out:
# list

# %%
# ahh it's a list! - now I get it. It's a list of songs. So I better index it. 
results['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
# ...

# %%
#looks like this in another dictionary! - ok lets check the keys
results['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
#Nice. So now I an use the key to get at the information I need. 
#What is the duration on the first song by lada gag on spotify?
results['tracks']['items'][0]['duration_ms']
# Out:
# 294573

# %%
#humm. And what album is it on?
results['tracks']['items'][0]['album']
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#    'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#    'id': '1HY2Jd0NmPuamShAr6KMms',
#    'name': 'Lady Gaga',
#    'type': 'artist',
#    'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BZ',
#   'CA',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
# ...

# %%
#Damn its another nested dictionary! 
results['tracks']['items'][0]['album'].keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
#and so on and so forth

# %% [markdown]
# #### Activity 1

# %%
my_lst = ['Elvis Presley', 'The Beatles', 'The Rolling Stones', 'The Clash', 'The Stranglers']

# %%
#Turn this into a dictionary with keys and values. Use Dictionary comprehension like this: 
my_dic = {i;sp.search(q=i, limit=50) for i in my_lst}
# Out:
#   File "<ipython-input-82-280ee8786e5f>", line 2
#     my_dic = {i;sp.search(q=i, limit=50) for i in my_lst}
#                ^
# SyntaxError: invalid syntax

# %%
#as a for loop:
for i in my_lst:
    print(sp.search(q=i, limit=50))
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Elvis+Presley&type=track&offset=0&limit=50', 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/43ZHCT0cAZBISjO8DG9PnE'}, 'href': 'https://api.spotify.com/v1/artists/43ZHCT0cAZBISjO8DG9PnE', 'id': '43ZHCT0cAZBISjO8DG9PnE', 'name': 'Elvis Presley', 'type': 'artist', 'uri': 'spotify:artist:43ZHCT0cAZBISjO8DG9PnE'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB
# ...

# %%
#as a list comprehension
my_5_artists = [sp.search(q=i, limit=50) for i in my_lst]

# %%
my_5_artists.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-40743f2e53a9> in <module>
# ----> 1 my_5_artists.keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %% [markdown]
# ### Activity 2 - functions to get artist name and id

# %%
def get_artists_from_track(track):
    return [artist['name'] for artist in track['artists']]

def get_artists_id_from_track(track):
    return [artist['id'] for artist in track['artists']]

# %% [markdown]
# ### Activity 3 - playlists

# %% [markdown]
# Categories -> get all playlists in teh category for nigeria top 100 and -> get all the songs from that playlist (together with their audio feature)

# %%
# playlist link: https://open.spotify.com/playlist/75GeX247deNdTX7zdyZDnU?si=29f55c0ba7d84da0
# from this id: 75GeX247deNdTX7zdyZDnU

# %%
playlist = sp.user_playlist_tracks("patrickimoh", "75GeX247deNdTX7zdyZDnU")

# %%
len(playlist['items'])
# Out:
# 100
